# %%
import pandas as pd # Importing table from 2015

# %%
df = pd.read_csv('/Users/dmb/Desktop/IRONHACK/week3/weekley_project/archive/2015.csv') #Extract the informacion from first file from 2015
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
list(df.columns)
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual']

# %%
df[['Country', 'Region', 'Happiness Rank', 'Happiness Score','Health (Life Expectancy)','Trust (Government Corruption)','Freedom',]]
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Health (Life Expectancy)  Trust (Government Corruption)  \
# 0              7.587                   0.94143                        0.41978
# ...

# %%
df = df.drop(columns=['Family', 'Generosity', 'Dystopia Residual'], errors='ignore')
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)  Health (Life Expectancy)  \
# 0         0.03411                   1.39651                   0.94143
# 1         0.04884                   1.30232                   0.94784
# 2         0.03328                   1.32548                   0.87464
# 3         0.03880                   1.45900                   0.88521
# 4         0.03553                   1.32629                   0.90563
#
#    Freedom  Trust (Government Corruption)
# 0  0.66557                        0.41978
# 1  0.62877                        0.14145
# ...

# %%
df[['Country', 'Region', 'Happiness Rank', 'Happiness Score','Health (Life Expectancy)','Trust (Government Corruption)','Freedom',]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Health (Life Expectancy)       158 non-null    float64
#  5   Trust (Government Corruption)  158 non-null    float64
#  6   Freedom                        158 non-null    float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 8.8+ KB

# %%
data = [
    {"Country": "Switzerland", "Region": "Western Europe", "Happiness Rank": 1, "Happiness Score": 7.587, "Standard Error": 0.03411, "Economy (GDP per Capita)": 1.39651, "Health (Life Expectancy)": 0.94143, "Freedom": 0.66557, "Trust (Government Corruption)": 0.41978},
    {"Country": "Iceland", "Region": "Western Europe", "Happiness Rank": 2, "Happiness Score": 7.561, "Standard Error": 0.04884, "Economy (GDP per Capita)": 1.30232, "Health (Life Expectancy)": 0.94784, "Freedom": 0.62877, "Trust (Government Corruption)": 0.14145},
    {"Country": "Denmark", "Region": "Western Europe", "Happiness Rank": 3, "Happiness Score": 7.527, "Standard Error": 0.03328, "Economy (GDP per Capita)": 1.32548, "Health (Life Expectancy)": 0.87464, "Freedom": 0.64938, "Trust (Government Corruption)": 0.48357},
    {"Country": "Norway", "Region": "Western Europe", "Happiness Rank": 4, "Happiness Score": 7.522, "Standard Error": 0.03880, "Economy (GDP per Capita)": 1.45900, "Health (Life Expectancy)": 0.88521, "Freedom": 0.66973, "Trust (Government Corruption)": 0.36503},
    {"Country": "Canada", "Region": "North America", "Happiness Rank": 5, "Happiness Score": 7.427, "Standard Error": 0.03553, "Economy (GDP per Capita)": 1.32629, "Health (Life Expectancy)": 0.90563, "Freedom": 0.63297, "Trust (Government Corruption)": 0.32957}
]

# Create DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)  Health (Life Expectancy)  \
# 0         0.03411                   1.39651                   0.94143
# 1         0.04884                   1.30232                   0.94784
# 2         0.03328                   1.32548                   0.87464
# 3         0.03880                   1.45900                   0.88521
# 4         0.03553                   1.32629                   0.90563
#
#    Freedom  Trust (Government Corruption)
# 0  0.66557                        0.41978
# 1  0.62877                        0.14145
# ...

# %%
df.nunique()
# Out:
# Country                          158
# Region                            10
# Happiness Rank                   157
# Happiness Score                  157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# dtype: int64

# %%
df.isna().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# dtype: int64

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Economy (GDP per Capita)         float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.to_csv('/Users/dmb/Desktop/IRONHACK/week3/weekley_project/archive/2015_table_02.csv', index=True) #exporting

# %%
import pandas as pd  # Importing table from 2016
df = pd.read_csv('/Users/dmb/Desktop/IRONHACK/week3/weekley_project/archive/2016.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
df = df.drop(columns=['Family', 'Dystopia.Residual','Lower Confidence Interval','Upper Confidence Interval'], errors='ignore')
df.head()  # Droping columns that will not be considered into our data analysis
# Out:
#   country_name  avg_happiness_score
# 0  Switzerland                7.550
# 1      Iceland                7.532
# 2      Denmark                7.510
# 3       Norway                7.501
# 4       Canada                7.459

# %%
data = [
    {"Country": "Norway", "Happiness.Rank": 1, "Happiness.Score": 7.537, "Economy..GDP.per.Capita.": 1.616463, "Health..Life.Expectancy.": 0.796667, "Freedom": 0.635423, "Trust..Government.Corruption.": 0.315964},
    {"Country": "Denmark", "Happiness.Rank": 2, "Happiness.Score": 7.522, "Economy..GDP.per.Capita.": 1.482383, "Health..Life.Expectancy.": 0.792566, "Freedom": 0.626007, "Trust..Government.Corruption.": 0.400770},
    {"Country": "Iceland", "Happiness.Rank": 3, "Happiness.Score": 7.504, "Economy..GDP.per.Capita.": 1.480633, "Health..Life.Expectancy.": 0.833552, "Freedom": 0.627163, "Trust..Government.Corruption.": 0.153527},
    {"Country": "Switzerland", "Happiness.Rank": 4, "Happiness.Score": 7.494, "Economy..GDP.per.Capita.": 1.564980, "Health..Life.Expectancy.": 0.858131, "Freedom": 0.620071, "Trust..Government.Corruption.": 0.367007},
    {"Country": "Finland", "Happiness.Rank": 5, "Happiness.Score": 7.469, "Economy..GDP.per.Capita.": 1.443572, "Health..Life.Expectancy.": 0.809158, "Freedom": 0.617951, "Trust..Government.Corruption.": 0.382612}
]

# Create the DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#        Country  Happiness.Rank  Happiness.Score  Economy..GDP.per.Capita.  \
# 0       Norway               1            7.537                  1.616463
# 1      Denmark               2            7.522                  1.482383
# 2      Iceland               3            7.504                  1.480633
# 3  Switzerland               4            7.494                  1.564980
# 4      Finland               5            7.469                  1.443572
#
#    Health..Life.Expectancy.   Freedom  Trust..Government.Corruption.
# 0                  0.796667  0.635423                       0.315964
# 1                  0.792566  0.626007                       0.400770
# 2                  0.833552  0.627163                       0.153527
# 3                  0.858131  0.620071                       0.367007
# 4                  0.809158  0.617951                       0.382612

# %%
df.dtypes
# Out:
# Country                           object
# Happiness.Rank                     int64
# Happiness.Score                  float64
# Economy..GDP.per.Capita.         float64
# Health..Life.Expectancy.         float64
# Freedom                          float64
# Trust..Government.Corruption.    float64
# dtype: object

# %%
df.nunique()
# Out:
# Country                          157
# Region                            10
# Happiness Rank                   154
# Happiness Score                  154
# Lower Confidence Interval        154
# Upper Confidence Interval        154
# Economy (GDP per Capita)         157
# Family                           157
# Health (Life Expectancy)         156
# Freedom                          157
# Trust (Government Corruption)    156
# Generosity                       157
# Dystopia Residual                157
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.drop(columns=['Family', 'Generosity', 'Dystopia.Residual','Whisker.high','Whisker.low'], errors='ignore')
df.head() # Droping columns that will not be considered into our data analysis
# Out:
#        Country  Happiness.Rank  Happiness.Score  Economy..GDP.per.Capita.  \
# 0       Norway               1            7.537                  1.616463
# 1      Denmark               2            7.522                  1.482383
# 2      Iceland               3            7.504                  1.480633
# 3  Switzerland               4            7.494                  1.564980
# 4      Finland               5            7.469                  1.443572
#
#    Health..Life.Expectancy.   Freedom  Trust..Government.Corruption.
# 0                  0.796667  0.635423                       0.315964
# 1                  0.792566  0.626007                       0.400770
# 2                  0.833552  0.627163                       0.153527
# 3                  0.858131  0.620071                       0.367007
# 4                  0.809158  0.617951                       0.382612

# %%
df.to_csv('/Users/dmb/Desktop/IRONHACK/week3/weekley_project/archive/2016_table_03.csv', index=True) #exporting

# %%
import pandas as pd # Importing table from 2017

# %%
df = pd.read_csv('/Users/dmb/Desktop/IRONHACK/week3/weekley_project/archive/2017.csv')
df
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
df = df.drop(columns=['Family', 'Generosity', 'Dystopia.Residual','Whisker.high','Whisker.low'], errors='ignore')
df.head()  # Droping columns that will not be considered into our data analysis
# Out:
#        Country  Happiness.Rank  Happiness.Score  Economy..GDP.per.Capita.  \
# 0       Norway               1            7.537                  1.616463
# 1      Denmark               2            7.522                  1.482383
# 2      Iceland               3            7.504                  1.480633
# 3  Switzerland               4            7.494                  1.564980
# 4      Finland               5            7.469                  1.443572
#
#    Health..Life.Expectancy.   Freedom  Trust..Government.Corruption.
# 0                  0.796667  0.635423                       0.315964
# 1                  0.792566  0.626007                       0.400770
# 2                  0.833552  0.627163                       0.153527
# 3                  0.858131  0.620071                       0.367007
# 4                  0.809158  0.617951                       0.382612

# %%
data = {
    "Country": ["Norway", "Denmark", "Iceland", "Switzerland", "Finland"],
    "Happiness.Rank": [1, 2, 3, 4, 5],
    "Happiness.Score": [7.537, 7.522, 7.504, 7.494, 7.469],
    "Economy..GDP.per.Capita.": [1.616463, 1.482383, 1.480633, 1.564980, 1.443572],
    "Health..Life.Expectancy.": [0.796667, 0.792566, 0.833552, 0.858131, 0.809158],
    "Freedom": [0.635423, 0.626007, 0.627163, 0.620071, 0.617951],
    "Trust..Government.Corruption.": [0.315964, 0.400770, 0.153527, 0.367007, 0.382612]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display DataFrame
print(df)
# Out:
#        Country  Happiness.Rank  Happiness.Score  Economy..GDP.per.Capita.  \
# 0       Norway               1            7.537                  1.616463
# 1      Denmark               2            7.522                  1.482383
# 2      Iceland               3            7.504                  1.480633
# 3  Switzerland               4            7.494                  1.564980
# 4      Finland               5            7.469                  1.443572
#
#    Health..Life.Expectancy.   Freedom  Trust..Government.Corruption.
# 0                  0.796667  0.635423                       0.315964
# 1                  0.792566  0.626007                       0.400770
# 2                  0.833552  0.627163                       0.153527
# 3                  0.858131  0.620071                       0.367007
# 4                  0.809158  0.617951                       0.382612

# %%
df.nunique()
# Out:
# Country                          5
# Happiness.Rank                   5
# Happiness.Score                  5
# Economy..GDP.per.Capita.         5
# Health..Life.Expectancy.         5
# Freedom                          5
# Trust..Government.Corruption.    5
# dtype: int64

# %%
df.isna().sum()
# Out:
# Country                          0
# Happiness.Rank                   0
# Happiness.Score                  0
# Economy..GDP.per.Capita.         0
# Health..Life.Expectancy.         0
# Freedom                          0
# Trust..Government.Corruption.    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.to_csv('/Users/dmb/Desktop/IRONHACK/week3/weekley_project/archive/2017_table_02.csv', index=True) #exporting

# %%
import pandas as pd # Importing table from 2018
df = pd.read_csv('/Users/dmb/Desktop/IRONHACK/week3/weekley_project/archive/2018.csv')
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
df = df.drop(columns=['Score', 'Generosity', 'Social support'], errors='ignore')
df.head() # Droping columns that will not be considered into our data analysis
# Out:
#    Overall rank Country or region  GDP per capita  Healthy life expectancy  \
# 0             1           Finland           1.305                    0.874
# 1             2            Norway           1.456                    0.861
# 2             3           Denmark           1.351                    0.868
# 3             4           Iceland           1.343                    0.914
# 4             5       Switzerland           1.420                    0.927
#
#    Freedom to make life choices  Perceptions of corruption
# 0                         0.681                      0.393
# 1                         0.686                      0.340
# 2                         0.683                      0.408
# 3                         0.677                      0.138
# 4                         0.660                      0.357

# %%
data = {
    "Overall rank": [1, 2, 3, 4, 5],
    "Country or region": ["Finland", "Norway", "Denmark", "Iceland", "Switzerland"],
    "GDP per capita": [1.305, 1.456, 1.351, 1.343, 1.420],
    "Healthy life expectancy": [0.874, 0.861, 0.868, 0.914, 0.927],
    "Freedom to make life choices": [0.681, 0.686, 0.683, 0.677, 0.660],
    "Perceptions of corruption": [0.393, 0.340, 0.408, 0.138, 0.357]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display DataFrame
print(df)
# Out:
#    Overall rank Country or region  GDP per capita  Healthy life expectancy  \
# 0             1           Finland           1.305                    0.874
# 1             2            Norway           1.456                    0.861
# 2             3           Denmark           1.351                    0.868
# 3             4           Iceland           1.343                    0.914
# 4             5       Switzerland           1.420                    0.927
#
#    Freedom to make life choices  Perceptions of corruption
# 0                         0.681                      0.393
# 1                         0.686                      0.340
# 2                         0.683                      0.408
# 3                         0.677                      0.138
# 4                         0.660                      0.357

# %%
df.nunique()
# Out:
# Overall rank                    5
# Country or region               5
# GDP per capita                  5
# Healthy life expectancy         5
# Freedom to make life choices    5
# Perceptions of corruption       5
# dtype: int64

# %%
df.isna().sum()
# Out:
# Overall rank                    0
# Country or region               0
# GDP per capita                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Perceptions of corruption       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.to_csv('/Users/dmb/Desktop/IRONHACK/week3/weekley_project/archive/2018_table_02.csv', index=True) #exporting

# %%
import pandas as pd # Importing table from 2019
df = pd.read_csv('/Users/dmb/Desktop/IRONHACK/week3/weekley_project/archive/2019.csv')
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df = df.drop(columns=['Score', 'Generosity', 'Social support'], errors='ignore')
df.head()  # Droping columns that will not be considered into our data analysis
# Out:
#    Overall rank Country or region  GDP per capita  Healthy life expectancy  \
# 0             1           Finland           1.340                    0.986
# 1             2           Denmark           1.383                    0.996
# 2             3            Norway           1.488                    1.028
# 3             4           Iceland           1.380                    1.026
# 4             5       Netherlands           1.396                    0.999
#
#    Freedom to make life choices  Perceptions of corruption
# 0                         0.596                      0.393
# 1                         0.592                      0.410
# 2                         0.603                      0.341
# 3                         0.591                      0.118
# 4                         0.557                      0.298

# %%
data = {
    "Overall rank": [1, 2, 3, 4, 5],
    "Country or region": ["Finland", "Denmark", "Norway", "Iceland", "Netherlands"],
    "GDP per capita": [1.340, 1.383, 1.488, 1.380, 1.396],
    "Healthy life expectancy": [0.986, 0.996, 1.028, 1.026, 0.999],
    "Freedom to make life choices": [0.596, 0.592, 0.603, 0.591, 0.557],
    "Perceptions of corruption": [0.393, 0.410, 0.341, 0.118, 0.298]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#    Overall rank Country or region  GDP per capita  Healthy life expectancy  \
# 0             1           Finland           1.340                    0.986
# 1             2           Denmark           1.383                    0.996
# 2             3            Norway           1.488                    1.028
# 3             4           Iceland           1.380                    1.026
# 4             5       Netherlands           1.396                    0.999
#
#    Freedom to make life choices  Perceptions of corruption
# 0                         0.596                      0.393
# 1                         0.592                      0.410
# 2                         0.603                      0.341
# 3                         0.591                      0.118
# 4                         0.557                      0.298

# %%
df.nunique()
# Out:
# Overall rank                    5
# Country or region               5
# GDP per capita                  5
# Healthy life expectancy         5
# Freedom to make life choices    5
# Perceptions of corruption       5
# dtype: int64

# %%
df.isna().sum()
# Out:
# Overall rank                    0
# Country or region               0
# GDP per capita                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Perceptions of corruption       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.to_csv('/Users/dmb/Desktop/IRONHACK/week3/weekley_project/archive/2019_table_02.csv', index=True) #exporting

# %%
 # Happines Category - import four tables based in the categories in whoich we split our analysis 
import pandas as pd
df = pd.read_csv('/Users/dmb/Desktop/IRONHACK/week3/weekley_project/new tables/hapiness_category.csv')
df
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
#     country_name  avg_score happiness_category
# 0    Switzerland       7.55         Very happy
# 1        Iceland       7.53         Very happy
# 2        Denmark       7.51         Very happy
# 3         Norway       7.50         Very happy
# 4         Canada       7.46         Very happy
# ..           ...        ...                ...
# 153       Rwanda       3.47         Less happy
# 154        Benin       3.34         Less happy
# 155        Syria       3.01         Less happy
# 156      Burundi       2.91         Less happy
# 157         Togo       2.84         Less happy
#
# [158 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns

def plot_happiness_by_category(df):
    plt.figure(figsize=(12, 10))
    sns.barplot(
        data=df.sort_values("avg_score", ascending=False),
        x="avg_score", y="country_name", hue="happiness_category",
        palette={"Very happy": "green", "Moderately happy": "orange", "Less happy": "red"}
    )
    plt.title("Average Happiness Score by Country")
    plt.xlabel("Average Score")
    plt.ylabel("Country")
    plt.legend(title="Happiness Category")
    plt.tight_layout()
    plt.show()

# %%
data = {
    "country_name": ["Switzerland", "Iceland", "Denmark", "Norway", "Canada", 
                     "Rwanda", "Benin", "Syria", "Burundi", "Togo"],
    "avg_score": [7.55, 7.53, 7.51, 7.50, 7.46, 3.47, 3.34, 3.01, 2.91, 2.84],
    "happiness_category": ["Very happy"]*5 + ["Less happy"]*5
}

df = pd.DataFrame(data)

# %%
plot_happiness_by_category(df)

# %%
# Happines score table 
import pandas as pd
df = pd.read_csv('/Users/dmb/Desktop/IRONHACK/week3/weekley_project/new tables/max_min_hapiness-score.csv')
df
# Out:
#     country_name  max_happiness  min_happiness
# 0    Switzerland          7.587          7.537
# 1        Iceland          7.561          7.522
# 2        Denmark          7.527          7.504
# 3         Norway          7.522          7.494
# 4         Canada          7.469          7.427
# ..           ...            ...            ...
# 153       Rwanda          3.465          3.465
# 154        Benin          3.340          3.340
# 155        Syria          3.006          3.006
# 156      Burundi          2.905          2.905
# 157         Togo          2.839          2.839
#
# [158 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_happiness_range(df):
    df_melted = df.melt(id_vars=["country_name"], value_vars=["max_happiness", "min_happiness"],
                        var_name="Happiness Type", value_name="Happiness Score")

    plt.figure(figsize=(14, 8))
    sns.barplot(data=df_melted, x="country_name", y="Happiness Score", hue="Happiness Type")
    plt.xticks(rotation=90)
    plt.title("Max vs Min Happiness Scores by Country")
    plt.xlabel("Country")
    plt.ylabel("Happiness Score")
    plt.tight_layout()
    plt.show()

# %%
data = {
    "country_name": ["Switzerland", "Iceland", "Denmark", "Norway", "Canada", 
                     "Rwanda", "Benin", "Syria", "Burundi", "Togo"],
    "max_happiness": [7.587, 7.561, 7.527, 7.522, 7.469, 3.465, 3.340, 3.006, 2.905, 2.839],
    "min_happiness": [7.537, 7.522, 7.504, 7.494, 7.427, 3.465, 3.340, 3.006, 2.905, 2.839]
}

df = pd.DataFrame(data)

# %%
plot_happiness_range(df)

# %%
# standard deviation score by region table
import pandas as pd
df = pd.read_csv('/Users/dmb/Desktop/IRONHACK/week3/weekley_project/new tables/standard_deviation_score_by_region.csv')
df
# Out:
#                             region  std_dev_happiness
# 0        Australia and New Zealand              1.945
# 1                   Western Europe              1.594
# 2  Middle East and Northern Africa              1.073
# 3                Southeastern Asia              0.896
# 4      Latin America and Caribbean              0.712
# 5               Sub-Saharan Africa              0.602
# 6       Central and Eastern Europe              0.561
# 7                    Southern Asia              0.528
# 8                     Eastern Asia              0.506
# 9                    North America              0.137

# %%
import matplotlib.pyplot as plt


# Data defined
data = {
    "region": ["Australia and New Zealand", "Western Europe", "Middle East and Northern Africa", 
               "Southeastern Asia", "Latin America and Caribbean", "Sub-Saharan Africa", 
               "Central and Eastern Europe", "Southern Asia", "Eastern Asia", "North America"],
    "std_dev_happiness": [1.945, 1.594, 1.073, 0.896, 0.712, 0.602, 0.561, 0.528, 0.506, 0.137]
}

# Plot bar chart
plt.figure(figsize=(10, 6))
plt.barh(df["region"], df["std_dev_happiness"], color='skyblue')
plt.xlabel('Standard Deviation of Happiness')
plt.ylabel('Region')
plt.title('Standard Deviation of Happiness by Region')
plt.tight_layout()
plt.show()

df = pd.DataFrame(data)

# %%
import pandas as pd

df= pd.read_csv('/Users/dmb/Desktop/IRONHACK/week3/weekley_project/new tables/avg_hapiness-score.csv')
df
# Out:
#     country_name  avg_happiness_score
# 0    Switzerland                7.550
# 1        Iceland                7.532
# 2        Denmark                7.510
# 3         Norway                7.501
# 4         Canada                7.459
# ..           ...                  ...
# 153       Rwanda                3.465
# 154        Benin                3.340
# 155        Syria                3.006
# 156      Burundi                2.905
# 157         Togo                2.839
#
# [158 rows x 2 columns]

# %%
import seaborn as sns
plt.figure(figsize=(14, 6))
plt.plot(df_sorted["country_name"], df_sorted["avg_happiness_score"], marker='o', color='green')
plt.xticks(rotation=90)
plt.ylabel("Average Happiness Score")
plt.title("Happiness Score Trend by Country")
plt.tight_layout()
plt.show()
